# %% [markdown]
# <a href="https://colab.research.google.com/github/ali77sina/Motion_Detection_Arduino/blob/main/Data_Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This is a simple code for you to be able to visualize and see your data.

# %%
#importing relevant libraries 
import numpy as np
import matplotlib.pyplot as plt

# %%
num = 50    #random set of data to visualize
flname=open("accver"+str(num),'r')   #"acchor" is the prefix for the data to do with horizontal motion, change this to match your application. 
data = flname.read()
data = data.split('b')    #data saved in format: b'132', meaning 132 in bytes. 

#The following is just a manual piece of code to save the data in numpy arrays
#This is purely based on how your Arduino is printing the data
#Change this bit to match your application. 

data2 = []
for i in data:
    data2.append(i.split(','))
del(data2[0])

for i in range(len(data2)):
    data2[i][-1] = float(data2[i][-1][0:4])
    data2[i][0] = float(data2[i][0][1:5])
    data2[i][1] = float(data2[i][1])

# %% [markdown]
# This step is somewhat essential for you to see that you have "reliable" data, at least at a visual level. Below is an example of the motion for a horizental movement.
#
# ![oxar.png](data:image/png;base64,...)
